# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# !gdown 16j8aIfF37MATU4zF6wNtT7lWLbK7shKx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16j8aIfF37MATU4zF6wNtT7lWLbK7shKx
# To: /content/augmented_data_set_247756.csv
# 100% 1.13G/1.13G [00:08<00:00, 141MB/s]

# %%
df = pd.read_csv('/content/augmented_data_set_247756.csv').drop(['Unnamed: 0'], axis=1)

# %%
length = len(df)

# %%
length//2994
# Out:
# 82

# %%
splits = np.array_split(df, 82)

# %%
gdrive_path = '/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/AI 기반 회의 녹취록 요약 경진대회/data/aug_splits'

# %%
num = 1
for split in splits:
    split.to_csv(f'{gdrive_path}/augmented_{num}.csv', index=False)
    num += 1
